# %%
import os

# %%
file = open("long-doc.txt",'r')
lines = file.readlines()
file.close()

# %%
print( len(lines), type(lines))
print( '\n', len(lines[0]), '\n', lines[0])
# Out:
# 1 <class 'list'>
#
#  114000
# ...

# %%
all = "".join( lines )
print( len(all), type(all))
print( all )
all = all.lower()
print( all )
# Out:
# 114000 <class 'str'>
# ...

# %%
a = {  chr(i): all.count(chr(i)) for i in range(97,123)}
for key, value in a.items():
    print( f"'{key}': {value}" )
# print( a )
# Out:
# 'a': 4000
# 'b': 0
# 'c': 6000
# 'd': 4000
# 'e': 10000
# 'f': 0
# 'g': 2000
# 'h': 0
# 'i': 12000
# 'j': 0
# 'k': 0
# 'l': 6000
# 'm': 6000
# 'n': 4000
# 'o': 8000
# 'p': 4000
# 'q': 0
# 'r': 6000
# 's': 8000
# 't': 10000
# 'u': 4000
# 'v': 0
# 'w': 0
# 'x': 0
# 'y': 0
# 'z': 0

# %%
b = a.copy()
sorted_b = dict(
                sorted(b.items(), key=lambda item: item[1], reverse=True)
            )
print( sorted_b)
# Out:
# {'i': 12000, 'e': 10000, 't': 10000, 'o': 8000, 's': 8000, 'c': 6000, 'l': 6000, 'm': 6000, 'r': 6000, 'a': 4000, 'd': 4000, 'n': 4000, 'p': 4000, 'u': 4000, 'g': 2000, 'b': 0, 'f': 0, 'h': 0, 'j': 0, 'k': 0, 'q': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0}

# %%
my_tuple = (0,1,2,3,4,5)
foo = list(filter(lambda x: x-0 and x-1, my_tuple))
# foo = list(filter(lambda x: x==0 and x==1, my_tuple))
print(foo )
# Out:
# [2, 3, 4, 5]

# %%
for x in open("long-doc.txt",'r'):
    print(x)
# Out:
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Lorem ipsum dolor sit amet, c
# ...

# %%
# 1
from datetime import timedelta
delta = timedelta(weeks=1, days=7, hours=11)
print( delta * 2 )
# Out:
# 28 days, 22:00:00

# %%
# 2
class Class:
    def __init__(self, val=0):
        pass

# obj = Class(1,2) # is invalid

# %%
# 5
from datetime import datetime
datetime1 = datetime(2019, 11, 27, 11, 27, 22)
datetime2 = datetime(2019, 11, 27, 0, 0, 0)
print( datetime1 - datetime2 )
# Out:
# 11:27:22

# %%
# 9
class A:
    def __init__(self, v=2):
        self.v = v

    def set(self,v=1):
        self.v += v
        return self.v

a = A()
b = a
b.set()
print( a.v)
# Out:
# 3

# %%
for x in open("notesKQL.txt",'rt'):
    # print(x)
    pass
# line by line

# %%
# 11
import random

a = random.randint(0,100)
b = random.randrange(10,100, 3)
c = random.choice((0,100,3))
print( a, b , c )
# Out:
# 37 79 0

# %%
class A:
    A = 1
    def __init__(self):
        self.a = 0

print( hasattr(A, 'a') )
# Out:
# False

# %%
# 13
class A:
    def __init__(self, v):
        self.__a = v + 1

a = A(0)
print( a.__a ) # error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 7
#       4         self.__a = v + 1
#       6 a = A(0)
# ----> 7 print( a.__a ) # error
#
# AttributeError: 'A' object has no attribute '__a'

# %%
print( chr(ord('p') + 0) )
print( chr(ord('p') + 1) )
print( chr(ord('p') + 2) )
# Out:
# p
# q
# r

# %%
# 29
x = "\\\\"
print( len(x) )
# Out:
# 2

# %%
class A:
    pass

class B(A):
    pass

class C(B):
    pass

print( issubclass(A,C) )
print( issubclass(C,A) )
# Out:
# False
# True

# %%
numbers = [ i*i for i in range(5) ]
foo1 = list( filter( lambda x: x%2 , numbers ) )
foo2 = list(map( lambda x: x // 2 , foo ) )
foo3 = list(map( lambda x: x % 2 , foo ))
foo4 = list( filter( lambda x: x/2 , numbers ) )

print( numbers )
print(foo1)
print(foo2)
print(foo3)
print(foo4)
print( 9 % 2 )
# Out:
# [0, 1, 4, 9, 16]
# [1, 9]
# [1, 1, 2, 2]
# [0, 1, 0, 1]
# [1, 4, 9, 16]
# 1

# %%
file = open("long-doc.txt",'w+')
print( file.name)
# Out:
# long-doc.txt

# %%
print( sorted('Radek Turek'))
# Out:
# [' ', 'R', 'T', 'a', 'd', 'e', 'e', 'k', 'k', 'r', 'u']
